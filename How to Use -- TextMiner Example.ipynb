# %% [markdown]
# # Text Mining Example - TextMiner

# %% [markdown]
# ## Installation

# %%
## Install Library
#!pip install textmining-module==0.1.4
#https://pypi.org/project/textmining-module/

# %% [markdown]
# ### Package

# %%
## Load up Library
from textmining_module import TextMiner
from textmining_module import KeywordsExtractor

# %% [markdown]
# ### Data Exploration

# %%
## Sample Data

import pandas as pd
import numpy as np

data = pd.read_csv("C:/Users/kwadw.DESKTOP-T9BSTPE/OneDrive/Desktop/My Python Packages/backwardsreg/sephora_reviews.csv")

# %%
## Top rows of data
data.head(10)
# Out:
#                                                  url  \
# 0  https://www.sephora.com/ca/en/product/k-by-dol...
# 1  https://www.sephora.com/ca/en/product/full-cov...
# 2  https://www.sephora.com/ca/en/product/pat-mcgr...
# 3  https://www.sephora.com/ca/en/product/teint-co...
# 4  https://www.sephora.com/ca/en/product/k-by-dol...
# 5  https://www.sephora.com/ca/en/product/versace-...
# 6  https://www.sephora.com/ca/en/product/full-cov...
# 7  https://www.sephora.com/ca/en/product/pat-mcgr...
# 8  https://www.sephora.com/ca/en/product/teint-co...
# 9  https://www.sephora.com/ca/en/product/k-by-dol...
#
#                                         name      pid             brand  \
# 0                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
# 1                       Full Cover Concealer  P151107  MAKE UP FOR EVER
# 2               Dark Star Volumizing Mascara  P460745  PAT McGRATH LABS
# 3  Teint Couture Everwear 24H Wear & Comfort  P443301          Givenchy
# 4                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
# 5                    Versace Man Eau Fraiche  P169301           Versace
# 6                       Full Cover Concealer  P151107  MAKE UP FOR EVER
# 7               Dark Star Volumizing Mascara  P460745  PAT McGRATH LABS
# 8  Teint Couture Everwear 24H Wear & Comfort  P443301          Givenchy
# 9                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
#
#                 breadcrumbs     user_name          review_title  rating  \
# 0                       Men  wildflower80    Worth the purchasr       5
# 1   Makeup, Face, Concealer  wildflower80    Worth the purchasr       5
# 2      Makeup, Eye, Mascara  wildflower80    Worth the purchasr       5
# 3  Makeup, Face, Foundation  wildflower80    Worth the purchasr       5
# 4                       Men     regina881                   NaN       2
# 5   Fragrance, Men, Cologne  wildflower80    Worth the purchasr       5
# 6   Makeup, Face, Concealer     regina881                   NaN       2
# 7      Makeup, Eye, Mascara     regina881                   NaN       2
# 8  Makeup, Face, Foundation     regina881                   NaN       2
# 9                       Men  ErinEngraved  Like Cigarette Smoke       2
#
#                                          review_text  helpful_count  images  \
# 0  Love the scent of this candle and the beautifu...       1.000000     NaN
# 1  Love the scent of this candle and the beautifu...       1.000000     NaN
# 2  Love the scent of this candle and the beautifu...       1.000000     NaN
# 3  Love the scent of this candle and the beautifu...       1.000000     NaN
# 4  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 5  Love the scent of this candle and the beautifu...       1.000000     NaN
# 6  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 7  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 8  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 9  This smells great in the container. I lot this...       0.714286     NaN
#
#   reviewed_at                               uniq_id  scraped_at
# 0  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03
# 1  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03
# 2  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03
# 3  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03
# 4  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03
# 5  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03
# 6  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03
# 7  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03
# 8  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03
# 9  2021-05-15  e3343544-6a6d-5e9b-b4de-e0f4bb12fc1f  2022-08-03

# %%
## Adding a target column for reviews 
data['status'] = data['rating'].apply(lambda x: "Perfect" if x == 5 else "Not-Perfect")

# %% [markdown]
# ### Format of Code - TextMiner

# %% [markdown]
# ``` bash
#
# text_modeling = TextMiner(data,
#                  comment_variable='Cleaned_text_column', target_variable='Target_column',
#                  strata_variable='LoB_column', keywords_variable=None, clean_words=None,  # data
#                  search_mode='micro', n=3, top=1, stop_words=None, truncation_words=None, truncation_mode='right', # YAKE
#                  fpg_min_support=1E-3, keep_strongest_association=False, removeOutersection=False, # FPG
#                  req_len_complexity=False, req_importance_score=False, # Random Forest
#                  verbose=True, preprocessing_only=False) # class use
# ```
#
# Here's a detailed look at each of its arguments:
#
# -   Required 1st argument : (`pandas` dataframe) of dataset;
# -   `comment_variable` : (str) name of the comment variable in `pandas`
#     dataframe;
# -   `target_variable` : (str) name of the target variable in `pandas`
#     dataframe;
# -   `truncation_words` : (str list) words where a split occur to
#     truncate a message to the left/right - i.e. if french copy
#     before/after an english message;
# -   `truncation_mode` : (str) {'right' : remove rhs of message at
#     truncation_word, 'left' : remove lhs of message at truncation_word};
# -   `preprocessing_only` : (bool) if True, only clean (opt.), format,
#     stratify (opt.) and truncate (opt.) given dataset;
# -   `verbose` : (bool) if True, show a progress bar.
# -   `strata_variable` : (str) name of the strata variable in `pandas`
#     dataframe, for a stratified analysis - i.e. break down by LoB;
# -   `req_len_complexity` : (bool) if True, include message length
#     quartiles in analysis as a new qualitative attribute;
# -   `removeOutersection` : (bool) if True, exclude keywords that contain
#     other fetched keywords;
# -   `search_mode` : (str) {'macro' : (for each strata) concatenate all
#     rows in one chunk before extracting keywords, 'micro' or 'macro' : extract
#     keywords row-wise}
# -   `n` : (int) maximal number of grams (words excluding `stop_words`)
#     that can form a `keyword`;
# -   `top` : (int) how many n-grams to fetch;
# -   `stop_words` : (str list) words to disregard in generation of
#     n-grams;
# -   `fpg_min_support` : (float) minimal support for FP Growth - try
#     higher value if FPG takes too long;
# -   `keep_strongest_association` : (bool) filter One Hot Data to keep
#     highest supported bits before fetching association.
# -   `req_importance_score`: (bool) find importance score for all bags of
#     relevant keywords

# %%
# Example usage

## Prepare Text Dataset
Cleaner = TextMiner(data, comment_variable='review_text', target_variable='status',
                       truncation_words=None, truncation_mode='right',
                       preprocessing_only=True, verbose=True)

data['Cleaned_review_text'] = Cleaner.reqCleanedData()['review_text']
# Out:
# FloatProgress(value=0.0, description='Init...', style=ProgressStyle(bar_color='#00AEFF', description_width='in…

# %%
## View data with clean text
data.head(10)
# Out:
#                                                  url  \
# 0  https://www.sephora.com/ca/en/product/k-by-dol...
# 1  https://www.sephora.com/ca/en/product/full-cov...
# 2  https://www.sephora.com/ca/en/product/pat-mcgr...
# 3  https://www.sephora.com/ca/en/product/teint-co...
# 4  https://www.sephora.com/ca/en/product/k-by-dol...
# 5  https://www.sephora.com/ca/en/product/versace-...
# 6  https://www.sephora.com/ca/en/product/full-cov...
# 7  https://www.sephora.com/ca/en/product/pat-mcgr...
# 8  https://www.sephora.com/ca/en/product/teint-co...
# 9  https://www.sephora.com/ca/en/product/k-by-dol...
#
#                                         name      pid             brand  \
# 0                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
# 1                       Full Cover Concealer  P151107  MAKE UP FOR EVER
# 2               Dark Star Volumizing Mascara  P460745  PAT McGRATH LABS
# 3  Teint Couture Everwear 24H Wear & Comfort  P443301          Givenchy
# 4                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
# 5                    Versace Man Eau Fraiche  P169301           Versace
# 6                       Full Cover Concealer  P151107  MAKE UP FOR EVER
# 7               Dark Star Volumizing Mascara  P460745  PAT McGRATH LABS
# 8  Teint Couture Everwear 24H Wear & Comfort  P443301          Givenchy
# 9                       K by Dolce & Gabbana  P449367   DOLCE & GABBANA
#
#                 breadcrumbs     user_name          review_title  rating  \
# 0                       Men  wildflower80    Worth the purchasr       5
# 1   Makeup, Face, Concealer  wildflower80    Worth the purchasr       5
# 2      Makeup, Eye, Mascara  wildflower80    Worth the purchasr       5
# 3  Makeup, Face, Foundation  wildflower80    Worth the purchasr       5
# 4                       Men     regina881                   NaN       2
# 5   Fragrance, Men, Cologne  wildflower80    Worth the purchasr       5
# 6   Makeup, Face, Concealer     regina881                   NaN       2
# 7      Makeup, Eye, Mascara     regina881                   NaN       2
# 8  Makeup, Face, Foundation     regina881                   NaN       2
# 9                       Men  ErinEngraved  Like Cigarette Smoke       2
#
#                                          review_text  helpful_count  images  \
# 0  Love the scent of this candle and the beautifu...       1.000000     NaN
# 1  Love the scent of this candle and the beautifu...       1.000000     NaN
# 2  Love the scent of this candle and the beautifu...       1.000000     NaN
# 3  Love the scent of this candle and the beautifu...       1.000000     NaN
# 4  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 5  Love the scent of this candle and the beautifu...       1.000000     NaN
# 6  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 7  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 8  Lovely scent in the jar, kind of smells like b...       0.500000     NaN
# 9  This smells great in the container. I lot this...       0.714286     NaN
#
#   reviewed_at                               uniq_id  scraped_at       status  \
# 0  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03      Perfect
# 1  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03      Perfect
# 2  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03      Perfect
# 3  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03      Perfect
# 4  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03  Not-Perfect
# 5  2021-09-01  e2bdc95f-a007-59e7-a615-662f5a1bc965  2022-08-03      Perfect
# 6  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03  Not-Perfect
# 7  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03  Not-Perfect
# 8  2021-06-12  24464c43-6264-5030-91e1-39687c5a4d53  2022-08-03  Not-Perfect
# 9  2021-05-15  e3343544-6a6d-5e9b-b4de-e0f4bb12fc1f  2022-08-03  Not-Perfect
#
#                                  Cleaned_review_text
# 0  love the scent of this candle and the beautifu...
# 1  love the scent of this candle and the beautifu...
# 2  love the scent of this candle and the beautifu...
# 3  love the scent of this candle and the beautifu...
# 4  lovely scent in the jar, kind of smells like b...
# 5  love the scent of this candle and the beautifu...
# 6  lovely scent in the jar, kind of smells like b...
# 7  lovely scent in the jar, kind of smells like b...
# 8  lovely scent in the jar, kind of smells like b...
# 9  this smells great in the container. i lot this...

# %%
## Stopwords to be removed
path_to_stopwords = "C:/Users/kwadw.DESKTOP-T9BSTPE/OneDrive/Desktop/My Python Packages/backwardsreg/stop_keywords.txt"
stopwords = open(path_to_stopwords, 'r').read().split('\n')

## Mining Stage
text_modeling = text_modeling = TextMiner(data, 
                 comment_variable='Cleaned_review_text', target_variable='status', 
                 strata_variable='brand', keywords_variable=None, clean_words=None,  # data
                 search_mode='micro', n=3, top=3, stop_words=stopwords, truncation_words=None, truncation_mode='right', # YAKE
                 fpg_min_support=1E-3, keep_strongest_association=True, removeOutersection=False, # FPG
                 req_len_complexity=False, req_importance_score=True, # Random Forest
                 verbose=True, preprocessing_only=False) # class use
# Out:
# FloatProgress(value=0.0, description='Init...', style=ProgressStyle(bar_color='#00AEFF', description_width='in…

# %%
## We can also request the strata of the data.

text_modeling.reqUniqueStratas()
# Out:
# ['DOLCE & GABBANA',
#  'MAKE UP FOR EVER',
#  'PAT McGRATH LABS',
#  'Givenchy',
#  'Versace',
#  'LAWLESS',
#  'IT Cosmetics',
#  'Tower 28 Beauty',
#  'HERMÈS',
#  'SEPHORA COLLECTION',
#  'The INKEY List',
#  'Laura Mercier',
#  'GUERLAIN',
#  'shu uemura',
#  'Josie Maran',
#  'Kate Somerville',
#  'Anastasia Beverly Hills',
#  'Juice Beauty',
#  'Montblanc',
#  'MILK MAKEUP',
#  'Danessa Myricks Beauty',
#  'CLINIQUE',
#  'Dr. Dennis Gross Skincare',
#  "Kiehl's Since 1851",
#  'Acqua di Parma',
#  'Lancôme',
#  'Too Faced',
#  'Dyson',
#  'Living Proof',
#  'Glow Recipe',
#  'Issey Miyake',
#  'Rare Beauty by Selena Gomez',
#  'La Mer',
#  'Bobbi Brown',
#  'HUDA BEAUTY',
#  'Jo Malone London',
#  'KVD Beauty',
#  'BeautyBio',
#  'NEST New York',
#  'By Rosie Jane',
#  'fresh',
#  'MAC Cosmetics',
#  'Mizani',
#  'tarte',
#  'Comptoir Sud Pacifique',
#  'StriVectin',
#  'NUDESTIX',
#  'Summer Fridays']

# %%
## We can also request the targets of the data.

text_modeling.reqUniqueTargets()
# Out:
# ['Perfect', 'Not-Perfect']

# %%
## We can also request the keywords extracted from the data per strata

text_modeling.reqYAKEKeywords()['DOLCE & GABBANA']
# Out:
#                                   Cleaned_review_text       status  \
# 0   love the scent of this candle and the beautifu...      Perfect
# 4   lovely scent in the jar, kind of smells like b...  Not-Perfect
# 9   this smells great in the container. i lot this...  Not-Perfect
# 14  this is my favorite scent from voluspa so far ...      Perfect
# 19  smells good but isn’t the strongest fragrance ...  Not-Perfect
# 24  i was very excited to see a new, fresh scent f...  Not-Perfect
# 51  this is really perfect for spring. it’s very r...      Perfect
# 59  love this scent, it is surprisingly refreshing...      Perfect
# 67  lovely scent! smells like spring time and not ...      Perfect
#
#                                         keywords_yake
# 0   [candle, beautiful jar, top makes, scent, love...
# 4   [burnt chocolate, lovely scent, kind of smells...
# 9            [smells great, container, smells, scent]
# 14  [favorite scent, coconut vanilla, tahtian coco...
# 19  [smells good, candle, n’t the strongest, smell...
# 24        [candle, perfect, apple blue clover, scent]
# 51       [perfect for spring, perfect, spring, scent]
# 59  [perfect for spring, candle, container, surpri...
# 67      [lovely scent, spring, lovely, smells, scent]

# %%
## Similarity Matrix 
## Note it compares keywords to keywords using its respective index.
## Example: a keyword on index 0 will be compare to a keyword of let's say index 5
text_modeling.reqSimilarityMatrix()['DOLCE & GABBANA']
# Out:
#           0         4         9         14        19        24        51  \
# 0   1.000000  0.090909  0.125000  0.125000  0.111111  0.285714  0.125000
# 4   0.090909  1.000000  0.222222  0.100000  0.090909  0.100000  0.100000
# 9   0.125000  0.222222  1.000000  0.142857  0.125000  0.142857  0.142857
# 14  0.125000  0.100000  0.142857  1.000000  0.000000  0.142857  0.142857
# 19  0.111111  0.090909  0.125000  0.000000  1.000000  0.125000  0.000000
# 24  0.285714  0.100000  0.142857  0.142857  0.125000  1.000000  0.333333
# 51  0.125000  0.100000  0.142857  0.142857  0.000000  0.333333  1.000000
# 59  0.166667  0.142857  0.181818  0.083333  0.076923  0.300000  0.444444
# 67  0.111111  0.500000  0.285714  0.125000  0.111111  0.125000  0.285714
#
#           59        67
# 0   0.166667  0.111111
# 4   0.142857  0.500000
# 9   0.181818  0.285714
# 14  0.083333  0.125000
# 19  0.076923  0.111111
# 24  0.300000  0.125000
# 51  0.444444  0.285714
# 59  1.000000  0.272727
# 67  0.272727  1.000000

# %%
## Clusterize
cluster_observations, cluster_keywords = text_modeling.clusterize(treshold=0.7)

# %%
cluster_observations['DOLCE & GABBANA']
# Out:
#     Cluster
# 0         4
# 4         1
# 9         2
# 14        5
# 19        6
# 24        3
# 51        3
# 59        3
# 67        1

# %%
cluster_keywords['DOLCE & GABBANA']
# Out:
#                            Cluster
# burnt chocolate                  4
# lovely scent                     4
# smells good                      3
# perfect for spring               6
# smells great                     5
# candle                           7
# container                        5
# surprisingly refreshing          6
# kind of smells                   4
# perfect                          6
# spring                           6
# n’t the strongest                3
# beautiful jar                    2
# smells like burnt                4
# favorite scent                   1
# perfect for springtime           6
# coconut vanilla                  1
# top makes                        2
# lovely                           4
# tahtian coconut vanilla          1
# smells                           4
# apple blue clover                8
# scent                            7
# strongest fragrance power        3
# love the scent                   2

# %%
## Attaching cluster to prepared dataframe
text_modeling.reqCleanedData()['DOLCE & GABBANA']
# Out:
#                                   Cleaned_review_text       status  \
# 0   love the scent of this candle and the beautifu...      Perfect
# 4   lovely scent in the jar, kind of smells like b...  Not-Perfect
# 9   this smells great in the container. i lot this...  Not-Perfect
# 14  this is my favorite scent from voluspa so far ...      Perfect
# 19  smells good but isn’t the strongest fragrance ...  Not-Perfect
# 24  i was very excited to see a new, fresh scent f...  Not-Perfect
# 51  this is really perfect for spring. it’s very r...      Perfect
# 59  love this scent, it is surprisingly refreshing...      Perfect
# 67  lovely scent! smells like spring time and not ...      Perfect
#
#                                         keywords_yake  Cluster
# 0   [candle, beautiful jar, top makes, scent, love...        4
# 4   [burnt chocolate, lovely scent, kind of smells...        1
# 9            [smells great, container, smells, scent]        2
# 14  [favorite scent, coconut vanilla, tahtian coco...        5
# 19  [smells good, candle, n’t the strongest, smell...        6
# 24        [candle, perfect, apple blue clover, scent]        3
# 51       [perfect for spring, perfect, spring, scent]        3
# 59  [perfect for spring, candle, container, surpri...        3
# 67      [lovely scent, spring, lovely, smells, scent]        1

# %%
## Scoring texts or keywords 
## NB: Remember to set req_importance_score = True
#text_modeling_fit = text_modeling.fit(n_round=10, n_fold=2, train_ratio=0.7, optim_metric='accuracy', n_jobs=1, skl_verbose=0, verbose=False)

text_modeling = TextMiner(data, comment_variable='Cleaned_review_text', target_variable='status', keywords_variable=None, strata_variable=None,
                        search_mode='micro', n=1, top=1, stop_words=stopwords,
                        fpg_min_support=1E-3, keep_strongest_association=False, removeOutersection=False,
                        preprocessing_only=False, req_len_complexity=False, req_importance_score= True, verbose=True)
# Out:
# FloatProgress(value=0.0, description='Init...', style=ProgressStyle(bar_color='#00AEFF', description_width='in…

# %%
## Fitting model
model = text_modeling.fit(k_neighbors=3, n_round=10, n_fold=2, train_ratio=0.8, optim_metric='accuracy',n_jobs=1, skl_verbose=0, verbose=False)

# %%
mdi_importances_df = pd.DataFrame(text_modeling.mdi_importances.items(), columns=['Feature', 'Importance'])
mdi_importances_df
# Out:
#      Feature  Importance
# 0     lovely    0.097086
# 1     smells    0.249514
# 2    vanilla    0.061522
# 3     candle    0.095939
# 4       love    0.106091
# 5  container    0.125884
# 6      scent    0.064893
# 7    perfect    0.199070

# %%
## Permutation
perm_importances_df = pd.DataFrame(text_modeling.perm_importances.items(), columns=['Feature', 'Importance'])
perm_importances_df
# Out:
#      Feature  Importance
# 0     lovely    0.075472
# 1     smells    0.235849
# 2    vanilla    0.005660
# 3     candle    0.041509
# 4       love    0.050943
# 5  container    0.000000
# 6      scent    0.000000
# 7    perfect    0.126415
